# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "self.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
#     "journal":{
#         "file": "self.bib",
#         "venuekey" : "journal",
#         "venue-pretext" : "",
#         "collection" : {"name":"publications",
#                         "permalink":"/publication/"}
#     } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
def original_fun():
    for pubsource in publist:
        parser = bibtex.Parser()
        bibdata = parser.parse_file(publist[pubsource]["file"])

        #loop through the individual references in a given bibtex file
        for bib_id in bibdata.entries:
            #reset default date
            pub_year = "1900"
            pub_month = "01"
            pub_day = "01"

            b = bibdata.entries[bib_id].fields

            try:
                pub_year = f'{b["year"]}'

                #todo: this hack for month and day needs some cleanup
                if "month" in b.keys(): 
                    if(len(b["month"])<3):
                        pub_month = "0"+b["month"]
                        pub_month = pub_month[-2:]
                    elif(b["month"] not in range(12)):
                        tmnth = strptime(b["month"][:3],'%b').tm_mon   
                        pub_month = "{:02d}".format(tmnth) 
                    else:
                        pub_month = str(b["month"])
                if "day" in b.keys(): 
                    pub_day = str(b["day"])


                pub_date = pub_year+"-"+pub_month+"-"+pub_day

                #strip out {} as needed (some bibtex entries that maintain formatting)
                clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

                url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
                url_slug = url_slug.replace("--","-")

                md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
                html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

                #Build Citation from text
                citation = ""

                #citation authors - todo - add highlighting for primary author?
                for author in bibdata.entries[bib_id].persons["author"]:
                    citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

                #citation title
                citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

                #add venue logic depending on citation type
                venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

                citation = citation + " " + html_escape(venue)
                citation = citation + ", " + pub_year + "."


                ## YAML variables
                md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'

                md += """collection: """ +  publist[pubsource]["collection"]["name"]

                md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename

                note = False
                if "note" in b.keys():
                    if len(str(b["note"])) > 5:
                        md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                        note = True

                md += "\ndate: " + str(pub_date) 

                md += "\nvenue: '" + html_escape(venue) + "'"

                url = False
                if "url" in b.keys():
                    if len(str(b["url"])) > 5:
                        md += "\npaperurl: '" + b["url"] + "'"
                        url = True

                md += "\ncitation: '" + html_escape(citation) + "'"

                md += "\n---"


                ## Markdown description for individual page
                if note:
                    md += "\n" + html_escape(b["note"]) + "\n"

                if url:
                    md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
                else:
                    md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

                md_filename = os.path.basename(md_filename)

                with open("../_publications/" + md_filename, 'w') as f:
                    f.write(md)
                print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
            # field may not exist for a reference
            except KeyError as e:
                print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
                continue

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

# %%
bibdata
# Out:
# BibliographyData(entries=OrderedCaseInsensitiveDict([('HuangLiLiuXu2016', Entry('article', fields=[('file', ':C$\\backslash$:/Users/DeLiu/Documents/Mendeley Desktop/Huang et al. - Unknown - Auctioning IT Service Contracts(4).pdf:pdf'), ('journal', 'Revising for Resubmission to Management Science'), ('title', '{Auctioning IT Service Contracts}')], persons=OrderedCaseInsensitiveDict([('author', [Person('Huang, He'), Person('Li, Zhipeng'), Person('Liu, De'), Person('Xu, Hongyan')])]))), ('Rui2011a', Entry('inproceedings', fields=[('address', 'Shanghai, China'), ('booktitle', 'Workshop on Information System Economics'), ('title', '{Optimal Allocation for Display Advertising}'), ('year', '2011')], persons=OrderedCaseInsensitiveDict([('author', [Person('Rui, Huaxia'), Person('Liu, De'), Person('Whinston, Andrew B.')])]))), ('CaiChanLiu2017wise', Entry('inproceedings', fields=[('address', 'Seoul, South Korea'), ('booktitle', 'Workshop on Economics of Information Systems (WISE)'), ('file', ':C$\\backslash$:/Users/DeLiu/Documents/Mendeley Desktop//Cai, Chan, Liu - Unknown - Better to Give Than to Receive Impacts of Donation-Based Contribution Schemes on Crowdfunding Outcomes.pdf:pdf'), ('title', '{Better to Give Than to Receive: Impacts of Donation-Based Contribution Schemes on Crowdfunding Outcomes}'), ('year', '2017')], persons=OrderedCaseInsensitiveDict([('author', [Person('Cai, Zhigang'), Person('Chan, Jason'), Person('Liu, De')])]))), ('Li2019', Entry('inproceedings', fields=[('address', 'Munich, Germany'), ('booktitle', 'ICIS 2019 Proceedings'), ('title', '{Re-engaging underachievers: toward a participation internalization approach to gamified online learning design}'), ('year', '2019')], persons=OrderedCaseInsensitiveDict([('author', [Person('Li, Tao'), Person('Liu, De'), Person('Xu, Xin')])]))), ('Ruia', Entry('article', fields=[('file', ':C$\\backslash$:/Users/DeLiu/Documents/Mendeley Desktop//Rui, Liu, Whinston - 2017 - Allocation and Pricing of Substitutable Goods Theory and Algorithm.pdf:pdf'), ('journal', 'Production and Operations Management'), ('number', '5'), ('pages', '767--783'), ('title', '{Allocation and Pricing of Substitutable Goods: Theory and Algorithm}'), ('volume', '26'), ('year', '2017')], persons=OrderedCaseInsensitiveDict([('author', [Person('Rui, Huaxia'), Person('Liu, De'), Person('Whinston, Andrew')])])))]), preamble=[])

# %%
def print_set(bibdata, keys):
    # loop through the individual references in a given bibtex file
    # need to provide a citation list, keys
    
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue

# %%
parser = bibtex.Parser()
bibdata = parser.parse_file("self.bib")

# %%
print_set(bibdata, [])
# Out:
# WARNING Missing Expected Field 'year' from entry HuangLiLiuXu2016: " {Auctioning IT Service Contrac ... "
# SUCESSFULLY PARSED Rui2011a: " {Optimal Allocation for Display Advertising}  "
# SUCESSFULLY PARSED CaiChanLiu2017wise: " {Better to Give Than to Receive: Impacts of Donation-Based C ... "
# SUCESSFULLY PARSED Li2019: " {Re-engaging underachievers: toward a participation internal ... "
# WARNING Missing Expected Field 'booktitle' from entry Ruia: " {Allocation and Pricing of Sub ... "

# %%
out = bibtex.format_from_files("self.bib", style='plain', citations=['*'])
# Out:
# ---------------------------------------------------------------------------
# TokenRequired                             Traceback (most recent call last)
# <ipython-input-22-887f47f07755> in <module>
# ----> 1 out = pybtex.format_from_files("self.bib", style='plain', citations=['CaiChanLiu2017wise'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\__init__.py in format_from_files(*args, **kwargs)
#     185 def format_from_files(*args, **kwargs):
#     186     """A convenience function that calls :py:meth:`.PybtexEngine.format_from_files`."""
# --> 187     return PybtexEngine().format_from_files(*args, **kwargs)
#     188
#     189
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\__init__.py in format_from_files(self, bib_files_or_filenames, style, citations, bib_format, bib_encoding, output_backend, output_encoding, min_crossrefs, output_filename, add_output_suffix, **kwargs)
#     152             wanted_entries=citations,
#     153             min_crossrefs=min_crossrefs,
# --> 154         ).parse_files(bib_files_or_filenames)
#     155
#     156         style_cls = find_plugin('pybtex.style.formatting', style)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\__init__.py in parse_files(self, base_filenames, file_suffix)
#      59     def parse_files(self, base_filenames, file_suffix=None):
#      60         for filename in base_filenames:
# ---> 61             self.parse_file(filename, file_suffix)
#      62         return self.data
#      63
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\__init__.py in parse_file(self, filename, file_suffix)
#      52         with open_file(filename, encoding=self.encoding) as f:
#      53             try:
# ---> 54                 self.parse_stream(f)
#      55             except UnicodeDecodeError as e:
#      56                 raise PybtexError(six.text_type(e), filename=self.filename)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\bibtex.py in parse_stream(self, stream)
#     408     def parse_stream(self, stream):
#     409         text = stream.read()
# --> 410         return self.parse_string(text)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\bibtex.py in parse_string(self, text)
#     395             macros=self.macros,
#     396         )
# --> 397         for entry in entry_iterator:
#     398             entry_type = entry[0]
#     399             entry_type_lower = entry_type.lower()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\bibtex.py in parse_bibliography(self)
#     193                 yield tuple(self.parse_command())
#     194             except PybtexSyntaxError as error:
# --> 195                 self.handle_error(error)
#     196             except SkipEntry:
#     197                 pass
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\bibtex.py in handle_error(self, error)
#     381     def handle_error(self, error):
#     382         from pybtex.errors import report_error
# --> 383         report_error(error)
#     384
#     385     def parse_string(self, text):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\errors.py in report_error(exception)
#      76
#      77     if strict:
# ---> 78         raise exception
#      79     else:
#      80         print_error(exception, 'WARNING: ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\bibtex.py in parse_bibliography(self)
#     191             self.command_start = self.pos - 1
#     192             try:
# --> 193                 yield tuple(self.parse_command())
#     194             except PybtexSyntaxError as error:
#     195                 self.handle_error(error)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\database\input\bibtex.py in parse_command(self)
#     205         name = self.required([self.NAME])
#     206         command = name.value
# --> 207         body_start = self.required([self.LPAREN, self.LBRACE])
#     208         body_end = self.RBRACE if body_start.pattern == self.LBRACE else self.RPAREN
#     209
#
# C:\ProgramData\Anaconda3\lib\site-packages\pybtex\scanner.py in required(self, patterns, description, allow_eof)
#     118             if not description:
#     119                 description = ' or '.join(pattern.description for pattern in patterns)
# --> 120             raise TokenRequired(description, self)
#     121         else:
#     122             return token
#
# TokenRequired: syntax error in line 38: '(' or '{' expected
